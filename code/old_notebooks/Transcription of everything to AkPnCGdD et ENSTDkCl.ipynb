# %%
import numpy as np
import mir_eval.transcription
import os
from IPython.display import display, Markdown

import transcribe_factorization as tf
import evaluate_transcription as et
import STFT
import pandas as pd

# %%
def printmd(string):
    display(Markdown(string))

def compute_scores_database(piano_type_W, piano_type_H, H_normalization = False, adaptative_threshold = True):
    path_computed_H = "../data_persisted/activations"
    path_songs = "C:/Users/amarmore/Desktop/Audio samples/MAPS/{}/MUS".format(piano_type_H)
    printmd("Piano for W: {}, and for H: {}".format(piano_type_W, piano_type_H))

    time_limit = 30
    beta = 1
    init = "L1"
    model_AD = True
    note_intensity = "M"
    itmax_H = 100
    tol = 1e-8
    codebook = range(21, 109)
    onset_tolerance = 50/1000
    
    #a = np.arange(1e-3, 1e-2, 1e-3)
    #b = np.arange(1e-4, 1e-3, 1e-4)
    #c = np.arange(1e-5, 1e-4, 1e-5)
    #d = np.arange(1e-6, 1e-5, 1e-6)
    f = np.arange(1e-2, 4e-1, 1e-2)
    #g = np.arange(0.3, 0.5, 0.1)
    #h = np.arange(1, 1.5, 0.1)
    #j = np.arange(1e-7, 1e-6, 1e-7)
    #listthres = np.r_[h[::-1], g[::-1], f[::-1], a[::-1], b[::-1], c[::-1], d[::-1], j[::-1]]
    listthres = np.r_[f[::-1]]

    files = os.listdir(path_songs)
    list_files_wav = []
    for it_files in files:
        if it_files.split(".")[-1] == "wav":
            list_files_wav.append(it_files)

    all_res = []
    for a_song in list_files_wav:
        song_name = a_song.replace(".wav", "")
        #print("processing piano song: {}".format(song_name))
        path_this_song = "{}/{}".format(path_songs, a_song)
        stft = STFT.STFT(path_this_song, time = time_limit, model_AD=model_AD, channel = 0)

        X = stft.get_magnitude_spectrogram()

        annot_name = a_song.replace("wav","txt")
        annot_this_song = "{}/{}".format(path_songs, annot_name)
        note_annotations = et.load_ref_in_array(annot_this_song, time_limit=time_limit)
        ref = np.array(note_annotations, float)
        ref_pitches = np.array(ref[:,2], int)
        try:
            #res_each_song = []
            res_a_param = []
            for T in [5, 10, 20]:
                H_persisted_name = "activations_song_{}_W_learned_{}_beta_{}_T_{}_init_{}_stftAD_{}_itmax_{}_intensity_W_{}_time_limit_{}_tol_{}".format(song_name, piano_type_W, beta, T, init, model_AD, itmax_H, note_intensity, time_limit, tol)
                H = np.load("{}/{}.npy".format(path_computed_H, H_persisted_name), allow_pickle = True)
                res_every_thresh = []
                for threshold in listthres:
                    if adaptative_threshold:
                        prediction, _ = tf.transcribe_activations_dynamic(codebook, H, stft, threshold, H_normalization = H_normalization)
                    else:
                        prediction, _ = tf.transcribe_activations(codebook, H, stft, threshold, H_normalization = H_normalization)
                    est = np.array(prediction, float)
                    if est.size > 0:
                        est_pitches = np.array(est[:,2], int)
                        (prec, rec, f_mes, _) = mir_eval.transcription.precision_recall_f1_overlap(ref[:,0:2], ref_pitches, est[:,0:2], est_pitches, offset_ratio = None, onset_tolerance = onset_tolerance)
                        matching = mir_eval.transcription.match_notes(ref[:,0:2], ref_pitches, est[:,0:2],est_pitches, onset_tolerance=onset_tolerance,offset_ratio=None)
                        TP = len(matching)
                        try:
                            FP = int(TP * (1 - prec) / prec)
                        except ZeroDivisionError:
                            FP = 0
                        try:
                            FN = int(TP * (1 - rec) / rec)
                        except ZeroDivisionError:
                            FN = 0
                        acc = et.accuracy(TP,FP,FN)
                    else:
                        prec, rec, f_mes, acc, TP, FP, FN = (0,0,0,0,0,0,0)
                    res_every_thresh.append([prec, rec, f_mes, acc, TP, FP, FN])
                res_a_param.append(res_every_thresh)
            #res_each_song.append(res_a_param)

            all_res.append(res_a_param)

        except FileNotFoundError:
            print("\033[91m This song failed: {} \033[00m".format(a_song)) 
            pass
    np_all_res = np.array(all_res)
    the_t = []
    for t in [5, 10, 20]:
        the_t.append("T: {}".format(t))
    index_pandas = the_t
    col = ['Best threshold','Precision', 'Recall', 'F measure','Accuracy','True Positives','False Positives','False Negatives']
    lines = []
    lines_opt_thresh = []
    for cond in range(len(index_pandas)):
        all_thresh = []
        for each_thresh in range(len(listthres)):
            all_thresh.append(np.mean(np_all_res[:,cond,each_thresh,2]))
        best_thresh_idx = np.argmax(all_thresh)
        this_line = [listthres[best_thresh_idx]]
        for i in range(len(col) - 1):# - 1 because threshold
            this_line.append(round(np.mean(np_all_res[:,cond,best_thresh_idx,i]), 4))
        lines.append(this_line)
        
        best_val = []
        for each_song in range(len(list_files_wav)):
            best_thresh_idx = np.argmax(np_all_res[each_song,cond,:,2])
            best_val.append([round(np_all_res[each_song,cond,best_thresh_idx,i], 4) for i in range(len(col) - 1)])
        lines_opt_thresh.append([round(np.mean(np.array(best_val)[:,i]),4) for i in range(len(col) - 1)])
    
    """printmd("### When averaging each threshold on all MAPS")
    df = pd.DataFrame(np.array(lines), columns = col, index = index_pandas)
    display(df.style.bar(subset=["F measure", "Accuracy"], color='#5fba7d'))

    printmd("### When optimizing the threshold on each song")
    best_df = pd.DataFrame(np.array(lines_opt_thresh), columns = col[1:], index = index_pandas)
    display(best_df.style.bar(subset=["F measure", "Accuracy"], color='#5fba7d'))"""
    
    return np.array(lines), np.array(lines_opt_thresh)

# %% [markdown]
# # Big table with all results

# %%
big_table_fix = []
big_table_opt = []
piano_W = []
piano_H = []
the_t = []
for piano_type_W in ["AkPnCGdD","ENSTDkCl","AkPnBcht","AkPnBsdf","AkPnStgb","ENSTDkAm","SptkBGAm","StbgTGd2"]:
    for piano_type_H in ["AkPnCGdD","ENSTDkCl"]:
        try:
            fix_thresh_cond, opt_thresh_cond = compute_scores_database(piano_type_W, piano_type_H, H_normalization = False, adaptative_threshold = True)
            for line_fix in fix_thresh_cond:
                big_table_fix.append(line_fix[:5])
            for line_opt in opt_thresh_cond:
                big_table_opt.append(line_opt[:4])
            for t in [5, 10, 20]:
                piano_W.append(f"W: {piano_type_W}")
                piano_H.append(f"H: {piano_type_H}")
                the_t.append(f"T: {t}")
        except IndexError:
            print("We have to compute this piano at these conditions (piano {}, T = 5, 10, 20, tol = 1e-8 and itmax = 100).".format(piano_type))
                               
printmd("## Fixing the threshold for all songs")
index_pandas = [np.array(piano_W), np.array(piano_H), np.array(the_t)]
col = ['Best threshold','Precision', 'Recall', 'F measure','Accuracy']
   
df = pd.DataFrame(np.array(big_table_fix), columns = col, index = index_pandas)
display(df.style.bar(subset=["F measure", "Accuracy"], color='#5fba7d'))

printmd("## Optimizing the threshold on each song")
df = pd.DataFrame(np.array(big_table_opt), columns = col[1:], index = index_pandas)
display(df.style.bar(subset=["F measure", "Accuracy"], color='#5fba7d'))
# Out:
# Piano for W: AkPnCGdD, and for H: AkPnCGdD
# Piano for W: AkPnCGdD, and for H: ENSTDkCl
# Piano for W: ENSTDkCl, and for H: AkPnCGdD
# Piano for W: ENSTDkCl, and for H: ENSTDkCl
# Piano for W: AkPnBcht, and for H: AkPnCGdD
# Piano for W: AkPnBcht, and for H: ENSTDkCl
# Piano for W: AkPnBsdf, and for H: AkPnCGdD
# Piano for W: AkPnBsdf, and for H: ENSTDkCl
# Piano for W: AkPnStgb, and for H: AkPnCGdD
# Piano for W: AkPnStgb, and for H: ENSTDkCl
# Piano for W: ENSTDkAm, and for H: AkPnCGdD
# Piano for W: ENSTDkAm, and for H: ENSTDkCl
# Piano for W: SptkBGAm, and for H: AkPnCGdD
# Piano for W: SptkBGAm, and for H: ENSTDkCl
# Piano for W: StbgTGd2, and for H: AkPnCGdD
# Piano for W: StbgTGd2, and for H: ENSTDkCl
# ## Fixing the threshold for all songs
# <style  type="text/css" >
#     #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 75.0%, transparent 75.0%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 70.8%, transparent 70.8%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 96.4%, transparent 96.4%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 95.3%, transparent 95.3%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 3.1%, transparent 3.1%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 3.2%, transparent 3.2%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 13.7%, transparent 13.7%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 11.5%, transparent 11.5%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 19.3%, transparent 19.3%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 16.2%, transparent 16.2%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 19.2%, transparent 19.2%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 16.4%, transparent 16.4%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row7_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 36.0%, transparent 36.0%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row7_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 30.8%, transparent 30.8%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row8_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 26.5%, transparent 26.5%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row8_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 21.2%, transparent 21.2%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row9_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 57.9%, transparent 57.9%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row9_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 52.5%, transparent 52.5%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row10_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 80.2%, transparent 80.2%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row10_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 76.9%, transparent 76.9%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row11_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 72.8%, transparent 72.8%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row11_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 68.0%, transparent 68.0%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row12_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 22.5%, transparent 22.5%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row12_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 19.7%, transparent 19.7%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row13_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 43.4%, transparent 43.4%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row13_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 38.0%, transparent 38.0%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row14_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 39.6%, transparent 39.6%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row14_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 33.6%, transparent 33.6%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row15_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 2.3%, transparent 2.3%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row15_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 2.7%, transparent 2.7%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row16_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 13.0%, transparent 13.0%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row16_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 10.9%, transparent 10.9%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row17_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 11.6%, transparent 11.6%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row17_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 9.6%, transparent 9.6%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row18_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 25.4%, transparent 25.4%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row18_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 21.2%, transparent 21.2%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row19_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 44.1%, transparent 44.1%);
#         }    #T_748e5d20_93b2_11eb_9655_8c04ba3e1d36row19_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 38.0%, transparent 38.0%);
#         }
# ## Optimizing the threshold on each song
# <style  type="text/css" >
#     #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 78.6%, transparent 78.6%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 74.1%, transparent 74.1%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 98.5%, transparent 98.5%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 98.3%, transparent 98.3%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 2.8%, transparent 2.8%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 2.8%, transparent 2.8%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 13.7%, transparent 13.7%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 11.5%, transparent 11.5%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 15.7%, transparent 15.7%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 13.2%, transparent 13.2%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 21.5%, transparent 21.5%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 18.0%, transparent 18.0%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 37.8%, transparent 37.8%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row7_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 32.2%, transparent 32.2%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 25.1%, transparent 25.1%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row8_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 20.4%, transparent 20.4%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 60.5%, transparent 60.5%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row9_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 54.9%, transparent 54.9%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row10_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 79.9%, transparent 79.9%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row10_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 76.3%, transparent 76.3%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row11_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 70.0%, transparent 70.0%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row11_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 65.0%, transparent 65.0%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row12_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 25.9%, transparent 25.9%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row12_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 22.2%, transparent 22.2%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row13_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 44.9%, transparent 44.9%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row13_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 39.3%, transparent 39.3%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row14_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 38.4%, transparent 38.4%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row14_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 32.6%, transparent 32.6%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row15_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 1.3%, transparent 1.3%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row15_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 1.4%, transparent 1.4%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row16_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 11.4%, transparent 11.4%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row16_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 9.3%, transparent 9.3%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row17_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 8.0%, transparent 8.0%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row17_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 6.9%, transparent 6.9%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row18_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 26.1%, transparent 26.1%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row18_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 21.8%, transparent 21.8%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row19_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 43.8%, transparent 43.8%);
#         }    #T_74b7ff45_93b2_11eb_b3e0_8c04ba3e1d36row19_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 37.8%, transparent 37.8%);
#         }
