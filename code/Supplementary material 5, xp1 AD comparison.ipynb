# %% [markdown]
# # Supplementary material 5: XP1 AD comparison

# %% [markdown]
# In this notebook, we provide codes to reproduce the transcription scores of the Attack Decay model with our post-processing and our data representation (no smoothing). For completeness, we also provide scores when performing peak-picking (todo if actual submission), and when using $H$ instead of $H^{attack}$ (AD paper suggests using $H^{attack}$ but the best choice depends actually on the piano and post-processing).

# %%
from compare_pianos_script import compute_scores_database_AD

# %% [markdown]
# The way to use our scripts is exactly the same as what is explained in the notebook `Supplementary material 1, xp1 and 2`.

# %%
for piano_type in ["AkPnCGdD","ENSTDkCl","AkPnBcht","AkPnBsdf","AkPnStgb","ENSTDkAm","SptkBGAm","StbgTGd2"]:
    compute_scores_database_AD(piano_type, H_normalization = False, fusion_peak= False, path_MAPS="/home/user/Travail/Toolbox/Data/Audio_Prozik/Maps/MAPS",
                              path_computed_H="../../data_persisted/activation_AD")
# Out:
# processing piano song: MAPS_MUS-liz_et_trans5_AkPnCGdD
# processing piano song: MAPS_MUS-muss_2_AkPnCGdD
# processing piano song: MAPS_MUS-ty_februar_AkPnCGdD
# processing piano song: MAPS_MUS-chpn_op27_1_AkPnCGdD
# processing piano song: MAPS_MUS-mendel_op53_5_AkPnCGdD
# processing piano song: MAPS_MUS-alb_esp3_AkPnCGdD
# processing piano song: MAPS_MUS-grieg_kobold_AkPnCGdD
# processing piano song: MAPS_MUS-chpn-p20_AkPnCGdD
# processing piano song: MAPS_MUS-chpn-p11_AkPnCGdD
# processing piano song: MAPS_MUS-waldstein_2_AkPnCGdD
# processing piano song: MAPS_MUS-chpn_op10_e12_AkPnCGdD
# processing piano song: MAPS_MUS-bk_xmas5_AkPnCGdD
# processing piano song: MAPS_MUS-chpn-p7_AkPnCGdD
# processing piano song: MAPS_MUS-chpn-p11-format0_AkPnCGdD
# processing piano song: MAPS_MUS-chp_op18_AkPnCGdD
# processing piano song: MAPS_MUS-liz_et5_AkPnCGdD
# processing piano song: MAPS_MUS-chpn-p13_AkPnCGdD
# processing piano song: MAPS_MUS-schu_143_2_AkPnCGdD
# ...

# %% [markdown]
# ### peak fusion

# %% [markdown]
# todo, improves some scores and decreases others.
