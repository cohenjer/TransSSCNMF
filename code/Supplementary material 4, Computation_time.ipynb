# %% [markdown]
# To be improved in final version

# %%
# Set root folder in ./code
import time

# %%
# Timing for tau 5, 10, 20, training phase
compt = []

# 5
t = time.time()
# %run launch_W_learning.py "AkPnCGdD" 5 "D:/Travail/Travail/Toolbox/Data/Audio_Prozik/Maps/MAPS"
compt.append(time.time()-t)

# 10
t = time.time()
# %run launch_W_learning.py "AkPnCGdD" 10 "D:/Travail/Travail/Toolbox/Data/Audio_Prozik/Maps/MAPS"
compt.append(time.time()-t)

# 20
t = time.time()
# %run launch_W_learning.py "AkPnCGdD" 20 "D:/Travail/Travail/Toolbox/Data/Audio_Prozik/Maps/MAPS"
compt.append(time.time()-t)
# Out:
# D:/Travail/Travail/Toolbox/Data/Audio_Prozik/Maps/MAPS
# MIDI:  100
# time:39.73146653175354
# MIDI:  103
# time:28.834205150604248
# MIDI:  104
# time:45.44029521942139
# MIDI:  105
# time:34.528377532958984
# MIDI:  106
# time:37.80535626411438
# MIDI:  21
# time:56.748570919036865
# MIDI:  22
# time:50.53792881965637
# MIDI:  24
# time:48.22782826423645
# MIDI:  25
# time:51.21153903007507
# MIDI:  26
# time:61.90625810623169
# MIDI:  27
# time:60.62409257888794
# MIDI:  28
# time:47.35703730583191
# MIDI:  30
# time:54.13619780540466
# MIDI:  34
# time:64.53364634513855
# MIDI:  35
# time:59.04094672203064
# MIDI:  36
# time:54.63998508453369
# MIDI:  37
# time:56.669700384140015
# MIDI:  41
# time:61.02720880508423
# MIDI:  42
# time:52.72667837142944
# MIDI:  44
# time:57.357664585113525
# MIDI:  48
# time:78.50414967536926
# MIDI:  49
# time:72.52660202980042
# MIDI:  51
# time:70.94849109649658
# MIDI:  54
# time:80.2749514579773
# MIDI:  57
# time:72.02345323562622
# ...

# %%
print(compt)
# Out:
# [4971.439457893372, 16945.310055971146, 55857.31552481651]

# %%
# Timing for tau 10, testing
compt2 = []
t = time.time()
# %run launch_H_learning.py "AkPnCGdD" "AkPnCGdD" 10 "D:/Travail/Travail/Toolbox/Data/Audio_Prozik/Maps/MAPS"
compt2 = time.time() - t
# Out:
# Piano templates learned on: AkPnCGdD
# processing piano song: MAPS_MUS-alb_esp2_AkPnCGdD
# Initialization is done
# Computation done
# Time: 257.118127822876
# processing piano song: MAPS_MUS-alb_esp3_AkPnCGdD
# Initialization is done
# Computation done
# Time: 262.2172055244446
# processing piano song: MAPS_MUS-bk_xmas5_AkPnCGdD
# Initialization is done
# Computation done
# Time: 262.58023619651794
# processing piano song: MAPS_MUS-bor_ps1_AkPnCGdD
# Initialization is done
# Computation done
# Time: 260.73585963249207
# processing piano song: MAPS_MUS-br_im2_AkPnCGdD
# Initialization is done
# Computation done
# Time: 262.6345489025116
# processing piano song: MAPS_MUS-br_im5_AkPnCGdD
# Initialization is done
# Computation done
# Time: 264.10465836524963
# processing piano song: MAPS_MUS-chpn-p11-format0_AkPnCGdD
# Initialization is done
# Computation done
# Time: 263.26922369003296
# processing piano song: MAPS_MUS-chpn-p11_AkPnCGdD
# Initialization is done
# Computation done
# ...

# %%
print(compt2)
# Out:
# 7183.885717630386
