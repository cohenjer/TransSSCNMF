# %%
import numpy as np
import mir_eval.transcription
import os
from IPython.display import display, Markdown

import transcribe_factorization as tf
import evaluate_transcription as et
import STFT
import pandas as pd

# %%
def compute_scores_database_one_condition(piano_type, T, note_intensity, H_normalization = False, adaptative_threshold = True):
    path_computed_H = "C:\\Users\\amarmore\\Desktop\\cnmf_res\\activations"
    path_songs = "C:\\Users\\amarmore\\Desktop\\Audio samples\\MAPS\\{}\\MUS".format(piano_type)
    
    time_limit = 30
    beta = 1
    init = "L1"
    model_AD = True
    itmax_H = 250
    tol = 1e-8
    codebook = range(21, 109)
    onset_tolerance = 50/1000
    
    #a = np.arange(1e-3, 1e-2, 1e-3)
    #b = np.arange(1e-4, 1e-3, 1e-4)
    #c = np.arange(1e-5, 1e-4, 1e-5)
    #d = np.arange(1e-6, 1e-5, 1e-6)
    f = np.arange(1e-2, 6e-1, 2e-2)
    #h = np.arange(1, 1.5, 0.1)
    #j = np.arange(1e-7, 1e-6, 1e-7)
    #listthres = np.r_[h[::-1], g[::-1], f[::-1], a[::-1], b[::-1], c[::-1], d[::-1], j[::-1]]
    listthres = np.r_[f[::-1]]

    files = os.listdir(path_songs)
    list_files_wav = []
    for it_files in files:
        if it_files.split(".")[-1] == "wav":
            list_files_wav.append(it_files)
            
    all_res = []
    for a_song in list_files_wav:
        song_name = a_song.replace(".wav", "")
        #print("processing piano song: {}".format(song_name))
        path_this_song = "{}\\{}".format(path_songs, a_song)
        stft = STFT.STFT(path_this_song, time = time_limit, model_AD=model_AD, channel = 0)

        X = stft.get_magnitude_spectrogram()
        H_persisted_name = "activations_song_{}_W_learned_{}_beta_{}_T_{}_init_{}_stftAD_{}_itmax_{}_intensity_W_{}_time_limit_{}_tol_{}".format(song_name, piano_type, beta, T, init, model_AD, itmax_H, note_intensity, time_limit, tol)

        annot_name = a_song.replace("wav","txt")
        annot_this_song = "{}/{}".format(path_songs, annot_name)
        note_annotations = et.load_ref_in_array(annot_this_song, time_limit=time_limit)
        ref = np.array(note_annotations, float)
        ref_pitches = np.array(ref[:,2], int)
        try:
            H = np.load("{}\\{}.npy".format(path_computed_H, H_persisted_name), allow_pickle = True)
            res_each_song = []
            for threshold in listthres:
                if adaptative_threshold:
                    prediction, _ = tf.transcribe_activations_dynamic(codebook, H, stft, threshold, H_normalization = H_normalization)
                else:
                    prediction, _ = tf.transcribe_activations(codebook, H, stft, threshold, H_normalization = H_normalization)
                est = np.array(prediction, float)
                if est.size > 0:
                    est_pitches = np.array(est[:,2], int)
                    (prec, rec, f_mes, _) = mir_eval.transcription.precision_recall_f1_overlap(ref[:,0:2], ref_pitches, est[:,0:2], est_pitches, offset_ratio = None, onset_tolerance = onset_tolerance)
                    matching = mir_eval.transcription.match_notes(ref[:,0:2], ref_pitches, est[:,0:2],est_pitches, onset_tolerance=onset_tolerance,offset_ratio=None)
                    TP = len(matching)
                    try:
                        FP = int(TP * (1 - prec) / prec)
                    except ZeroDivisionError:
                        FP = 0
                    try:
                        FN = int(TP * (1 - rec) / rec)
                    except ZeroDivisionError:
                        FN = 0
                    acc = et.accuracy(TP,FP,FN)
                else:
                    prec, rec, f_mes, acc, TP, FP, FN = (0,0,0,0,0,0,0)
                #TP_temp, FP_temp, FN_temp = et.compute_statistical_rates_on_array(note_annotations, prediction, onset_tolerance=onset_tolerance)
                res_each_song.append([prec, rec, f_mes, acc, TP, FP, FN])

            all_res.append(res_each_song)

        except FileNotFoundError:
            print("\033[91m This song failed: {} \033[00m".format(a_song)) 
            pass
        
    np_all_res = np.array(all_res)
    print(np_all_res.shape)
    col = ['Precision', 'Recall', 'F measure','Accuracy','True Positives','False Positives','False Negatives']

    lines = []
    for idx, threshold in enumerate(listthres):
        lines.append([round(np.mean(np_all_res[:,idx,i]), 4) for i in range(len(col))])
    df = pd.DataFrame(np.array(lines), columns = col, index = np.round(listthres,decimals = 5))
    display(df.style.bar(subset=["F measure", "Accuracy"], color='#5fba7d'))
    
    """best_val = []
    for each_song in range(len(list_files_wav)):
        best_thresh_idx = np.argmax(np_all_res[each_song,:,2])
        best_val.append([round(np_all_res[each_song,best_thresh_idx,i], 4) for i in range(len(col))])
    
    best_df = pd.DataFrame(np.array([np.mean(np.array(best_val)[:,i]) for i in range(len(col))]), columns = ["best res when optimizing thresh"], index = col)
    display(best_df.T)"""

# %% [markdown]
# # Score sans normalisation sur les H

# %%
print('piano_type = "AkPnCGdD", T = 5, note_intensity = "F"')
compute_scores_database_one_condition(piano_type = "AkPnCGdD", T = 5, note_intensity = "F", H_normalization = False)

print('piano_type = "AkPnCGdD", T = 5, note_intensity = "M"')
compute_scores_database_one_condition(piano_type = "AkPnCGdD", T = 5, note_intensity = "M", H_normalization = False)

#print('piano_type = "AkPnCGdD", T = 5, note_intensity = "P"')
#compute_scores_database_one_condition(piano_type = "AkPnCGdD", T = 5, note_intensity = "P", H_normalization = False)


print('\n piano_type = "ENSTDkCl", T = 5, note_intensity = "F"')
compute_scores_database_one_condition(piano_type = "ENSTDkCl", T = 5, note_intensity = "F", H_normalization = False)

print('piano_type = "ENSTDkCl", T = 5, note_intensity = "M"')
compute_scores_database_one_condition(piano_type = "ENSTDkCl", T = 5, note_intensity = "M", H_normalization = False)

#print('piano_type = "ENSTDkCl", T = 5, note_intensity = "P"')
#compute_scores_database_one_condition(piano_type = "ENSTDkCl", T = 5, note_intensity = "P", H_normalization = False)
# Out:
# piano_type = "AkPnCGdD", T = 5, note_intensity = "F"
# (30, 30, 7)
# <style  type="text/css" >
# #T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row0_col2,#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row0_col3{
#             width:  10em;
#              height:  80%;
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row1_col2,#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row1_col3,#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row2_col2,#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row2_col3,#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row3_col2,#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.0%, transparent 0.0%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row4_col2,#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.2%, transparent 0.2%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row4_col3,#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row5_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.1%, transparent 0.1%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row6_col2,#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row7_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.4%, transparent 0.4%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row6_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.3%, transparent 0.3%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.6%, transparent 0.6%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 1.0%, transparent 1.0%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row8_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.7%, transparent 0.7%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row9_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 1.6%, transparent 1.6%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row9_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 1.1%, transparent 1.1%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row10_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 2.3%, transparent 2.3%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row10_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 1.5%, transparent 1.5%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row11_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 3.7%, transparent 3.7%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row11_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 2.5%, transparent 2.5%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row12_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 5.2%, transparent 5.2%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row12_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 3.5%, transparent 3.5%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row13_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 7.0%, transparent 7.0%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row13_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 4.8%, transparent 4.8%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row14_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 9.1%, transparent 9.1%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row14_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 6.3%, transparent 6.3%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row15_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 11.6%, transparent 11.6%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row15_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 8.1%, transparent 8.1%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row16_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 15.2%, transparent 15.2%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row16_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 10.7%, transparent 10.7%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row17_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 20.0%, transparent 20.0%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row17_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 14.4%, transparent 14.4%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row18_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 25.2%, transparent 25.2%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row18_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 18.5%, transparent 18.5%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row19_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 31.8%, transparent 31.8%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row19_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 23.9%, transparent 23.9%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row20_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 39.8%, transparent 39.8%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row20_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 30.8%, transparent 30.8%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row21_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 50.6%, transparent 50.6%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row21_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 40.8%, transparent 40.8%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row22_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 60.5%, transparent 60.5%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row22_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 50.9%, transparent 50.9%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row23_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 70.8%, transparent 70.8%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row23_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 62.7%, transparent 62.7%);
#         }#T_39bda7ab_837d_11eb_a865_8c04ba3e1d36row24_col2{
# piano_type = "AkPnCGdD", T = 5, note_intensity = "M"
# (30, 30, 7)
# <style  type="text/css" >
# #T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row0_col2,#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row0_col3,#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row1_col2,#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row1_col3{
#             width:  10em;
#              height:  80%;
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row2_col2,#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row2_col3,#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row3_col2,#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.0%, transparent 0.0%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row4_col2,#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row5_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.2%, transparent 0.2%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.1%, transparent 0.1%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row5_col2,#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row6_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.3%, transparent 0.3%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row6_col2,#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row7_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.5%, transparent 0.5%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row7_col2,#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row9_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.8%, transparent 0.8%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 1.0%, transparent 1.0%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row8_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 0.6%, transparent 0.6%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row9_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 1.3%, transparent 1.3%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row10_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 1.8%, transparent 1.8%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row10_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 1.2%, transparent 1.2%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row11_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 2.5%, transparent 2.5%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row11_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 1.6%, transparent 1.6%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row12_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 3.8%, transparent 3.8%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row12_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 2.4%, transparent 2.4%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row13_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 5.6%, transparent 5.6%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row13_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 3.7%, transparent 3.7%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row14_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 7.8%, transparent 7.8%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row14_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 5.2%, transparent 5.2%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row15_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 11.0%, transparent 11.0%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row15_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 7.5%, transparent 7.5%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row16_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 14.9%, transparent 14.9%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row16_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 10.4%, transparent 10.4%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row17_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 19.4%, transparent 19.4%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row17_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 13.7%, transparent 13.7%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row18_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 24.3%, transparent 24.3%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row18_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 17.6%, transparent 17.6%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row19_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 30.6%, transparent 30.6%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row19_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 22.6%, transparent 22.6%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row20_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 39.2%, transparent 39.2%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row20_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 30.0%, transparent 30.0%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row21_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 50.2%, transparent 50.2%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row21_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 40.0%, transparent 40.0%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row22_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 62.0%, transparent 62.0%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row22_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 52.2%, transparent 52.2%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row23_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 72.5%, transparent 72.5%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row23_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 64.3%, transparent 64.3%);
#         }#T_c99733eb_837d_11eb_abdd_8c04ba3e1d36row24_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 82.7%, transparent 82.7%);
#         }#T_c99733eb
#  piano_type = "ENSTDkCl", T = 5, note_intensity = "F"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-e18fabf18e4d> in <module>
#      10
#      11 print('\n piano_type = "ENSTDkCl", T = 5, note_intensity = "F"')
# ---> 12 compute_scores_database_one_condition(piano_type = "ENSTDkCl", T = 5, note_intensity = "F", H_normalization = False)
#      13
#      14 print('piano_type = "ENSTDkCl", T = 5, note_intensity = "M"')
#
# <ipython-input-2-c3eb6a5c0868> in compute_scores_database_one_condition(piano_type, T, note_intensity, H_normalization, adaptative_threshold)
#      48             for threshold in listthres:
#      49                 if adaptative_threshold:
# ---> 50                     prediction, _ = tf.transcribe_activations_dynamic(codebook, H, stft, threshold, H_normalization = H_normalization)
#      51                 else:
#      52                     prediction, _ = tf.transcribe_activations(codebook, H, stft, threshold, H_normalization = H_normalization)
#
# ~\Desktop\Projects\PhD side projects\gf\f\code\transcribe_factorization.py in transcribe_activations_dynamic(midi_codebook, H, stft, threshold, sliding_window, H_normalization)
#     126             minimalSustainCondition = (H[note_index, time_index] - activation[note_index, time_index] > threshold * H_max) # actived note
#     127
# --> 128             if minimalSustainCondition: # note detected and sustained
#     129                 if not presence_of_a_note: # If the note hasn't been detected before
#     130                     try:
#
# KeyboardInterrupt:

# %% [markdown]
# # Score avec normalisation sur les H

# %%
print('piano_type = "AkPnCGdD", T = 5, note_intensity = "F"')
compute_scores_database_one_condition(piano_type = "AkPnCGdD", T = 5, note_intensity = "F", H_normalization = True)

print('piano_type = "AkPnCGdD", T = 5, note_intensity = "M"')
compute_scores_database_one_condition(piano_type = "AkPnCGdD", T = 5, note_intensity = "M", H_normalization = True)

print('piano_type = "AkPnCGdD", T = 5, note_intensity = "P"')
compute_scores_database_one_condition(piano_type = "AkPnCGdD", T = 5, note_intensity = "P", H_normalization = True)


print('\n piano_type = "ENSTDkCl", T = 5, note_intensity = "F"')
compute_scores_database_one_condition(piano_type = "ENSTDkCl", T = 5, note_intensity = "F", H_normalization = True)

print('piano_type = "ENSTDkCl", T = 5, note_intensity = "M"')
compute_scores_database_one_condition(piano_type = "ENSTDkCl", T = 5, note_intensity = "M", H_normalization = True)

print('piano_type = "ENSTDkCl", T = 5, note_intensity = "P"')
compute_scores_database_one_condition(piano_type = "ENSTDkCl", T = 5, note_intensity = "P", H_normalization = True)
