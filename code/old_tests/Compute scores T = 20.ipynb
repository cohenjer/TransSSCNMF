# %%
import numpy as np
import mir_eval.transcription
import os
from IPython.display import display, Markdown

import transcribe_factorization as tf
import evaluate_transcription as et
import STFT
import pandas as pd

# %%
def compute_scores_database_one_condition(piano_type, T, note_intensity, H_normalization = False, adaptative_threshold = True):
    path_computed_H = "C:\\Users\\amarmore\\Desktop\\cnmf_res\\activations"
    path_songs = "C:\\Users\\amarmore\\Desktop\\Audio samples\\MAPS\\{}\\MUS".format(piano_type)
    
    time_limit = 30
    beta = 1
    init = "L1"
    model_AD = True
    itmax_H = 250
    tol = 1e-8
    codebook = range(21, 109)
    onset_tolerance = 50/1000
    
    #a = np.arange(1e-3, 1e-2, 1e-3)
    #b = np.arange(1e-4, 1e-3, 1e-4)
    #c = np.arange(1e-5, 1e-4, 1e-5)
    #d = np.arange(1e-6, 1e-5, 1e-6)
    f = np.arange(1e-2, 6e-1, 2e-2)
    #g = np.arange(0.2, 0.5, 0.1)
    #h = np.arange(1, 1.5, 0.1)
    #j = np.arange(1e-7, 1e-6, 1e-7)
    #listthres = np.r_[h[::-1], g[::-1], f[::-1], a[::-1], b[::-1], c[::-1], d[::-1], j[::-1]]
    listthres = np.r_[f[::-1]]

    files = os.listdir(path_songs)
    list_files_wav = []
    for it_files in files:
        if it_files.split(".")[-1] == "wav":
            list_files_wav.append(it_files)
            
    all_res = []
    for a_song in list_files_wav:
        song_name = a_song.replace(".wav", "")
        #print("processing piano song: {}".format(song_name))
        path_this_song = "{}\\{}".format(path_songs, a_song)
        stft = STFT.STFT(path_this_song, time = time_limit, model_AD=model_AD, channel = 0)

        X = stft.get_magnitude_spectrogram()
        H_persisted_name = "activations_song_{}_W_learned_{}_beta_{}_T_{}_init_{}_stftAD_{}_itmax_{}_intensity_W_{}_time_limit_{}_tol_{}".format(song_name, piano_type, beta, T, init, model_AD, itmax_H, note_intensity, time_limit, tol)

        annot_name = a_song.replace("wav","txt")
        annot_this_song = "{}/{}".format(path_songs, annot_name)
        note_annotations = et.load_ref_in_array(annot_this_song, time_limit=time_limit)
        ref = np.array(note_annotations, float)
        ref_pitches = np.array(ref[:,2], int)
        try:
            H = np.load("{}\\{}.npy".format(path_computed_H, H_persisted_name), allow_pickle = True)
            res_each_song = []
            for threshold in listthres:
                if adaptative_threshold:
                    prediction, _ = tf.transcribe_activations_dynamic(codebook, H, stft, threshold, H_normalization = H_normalization)
                else:
                    prediction, _ = tf.transcribe_activations(codebook, H, stft, threshold, H_normalization = H_normalization)
                est = np.array(prediction, float)
                if est.size > 0:
                    est_pitches = np.array(est[:,2], int)
                    (prec, rec, f_mes, _) = mir_eval.transcription.precision_recall_f1_overlap(ref[:,0:2], ref_pitches, est[:,0:2], est_pitches, offset_ratio = None, onset_tolerance = onset_tolerance)
                    matching = mir_eval.transcription.match_notes(ref[:,0:2], ref_pitches, est[:,0:2],est_pitches, onset_tolerance=onset_tolerance,offset_ratio=None)
                    TP = len(matching)
                    try:
                        FP = int(TP * (1 - prec) / prec)
                    except ZeroDivisionError:
                        FP = 0
                    try:
                        FN = int(TP * (1 - rec) / rec)
                    except ZeroDivisionError:
                        FN = 0
                    acc = et.accuracy(TP,FP,FN)
                else:
                    prec, rec, f_mes, acc, TP, FP, FN = (0,0,0,0,0,0,0)
                #TP_temp, FP_temp, FN_temp = et.compute_statistical_rates_on_array(note_annotations, prediction, onset_tolerance=onset_tolerance)
                res_each_song.append([prec, rec, f_mes, acc, TP, FP, FN])

            all_res.append(res_each_song)

        except FileNotFoundError:
            print("\033[91m This song failed: {} \033[00m".format(a_song)) 
            pass
        
    np_all_res = np.array(all_res)
    col = ['Precision', 'Recall', 'F measure','Accuracy','True Positives','False Positives','False Negatives']

    lines = []
    for idx, threshold in enumerate(listthres):
        lines.append([round(np.mean(np_all_res[:,idx,i]), 4) for i in range(len(col))])
    df = pd.DataFrame(np.array(lines), columns = col, index = np.round(listthres,decimals = 5))
    display(df.style.bar(subset=["F measure", "Accuracy"], color='#5fba7d'))
    
    """best_val = []
    for each_song in range(len(list_files_wav)):
        best_thresh_idx = np.argmax(np_all_res[each_song,:,2])
        best_val.append([round(np_all_res[each_song,best_thresh_idx,i], 4) for i in range(len(col))])
    
    best_df = pd.DataFrame(np.array([np.mean(np.array(best_val)[:,i]) for i in range(len(col))]), columns = ["best res when optimizing thresh"], index = col)
    display(best_df.T)"""

# %% [markdown]
# # Sans normalisation des H

# %%
print('piano_type = "AkPnCGdD", T = 20, note_intensity = "F"')
compute_scores_database_one_condition(piano_type = "AkPnCGdD", T = 20, note_intensity = "F", H_normalization = False)

print('piano_type = "AkPnCGdD", T = 20, note_intensity = "M"')
compute_scores_database_one_condition(piano_type = "AkPnCGdD", T = 20, note_intensity = "M", H_normalization = False)

print('piano_type = "AkPnCGdD", T = 20, note_intensity = "P"')
compute_scores_database_one_condition(piano_type = "AkPnCGdD", T = 20, note_intensity = "P", H_normalization = False)


print('\n piano_type = "ENSTDkCl", T = 20, note_intensity = "F"')
compute_scores_database_one_condition(piano_type = "ENSTDkCl", T = 20, note_intensity = "F", H_normalization = False)

print('piano_type = "ENSTDkCl", T = 20, note_intensity = "M"')
compute_scores_database_one_condition(piano_type = "ENSTDkCl", T = 20, note_intensity = "M", H_normalization = False)

print('piano_type = "ENSTDkCl", T = 20, note_intensity = "P"')
compute_scores_database_one_condition(piano_type = "ENSTDkCl", T = 20, note_intensity = "P", H_normalization = False)
# Out:
#  piano_type = "ENSTDkCl", T = 20, note_intensity = "F"
# <style  type="text/css" >
# #T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 78.8%, transparent 78.8%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row0_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 73.2%, transparent 73.2%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 81.1%, transparent 81.1%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 75.8%, transparent 75.8%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 83.3%, transparent 83.3%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 78.5%, transparent 78.5%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 85.4%, transparent 85.4%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 81.3%, transparent 81.3%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.9%, transparent 86.9%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 83.2%, transparent 83.2%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 88.9%, transparent 88.9%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row5_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 85.6%, transparent 85.6%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 90.5%, transparent 90.5%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row6_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 87.6%, transparent 87.6%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 91.9%, transparent 91.9%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row7_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 89.7%, transparent 89.7%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 93.7%, transparent 93.7%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row8_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 91.7%, transparent 91.7%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row9_col2,#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row10_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 95.4%, transparent 95.4%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row9_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 94.1%, transparent 94.1%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row10_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 96.4%, transparent 96.4%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row11_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 97.2%, transparent 97.2%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row11_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 96.5%, transparent 96.5%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row12_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 97.9%, transparent 97.9%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row12_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 97.4%, transparent 97.4%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row13_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 98.9%, transparent 98.9%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row13_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 98.8%, transparent 98.8%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row14_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 99.2%, transparent 99.2%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row14_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 99.4%, transparent 99.4%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row15_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 99.7%, transparent 99.7%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row15_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 99.9%, transparent 99.9%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row16_col2,#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row16_col3,#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row17_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row17_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 99.8%, transparent 99.8%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row18_col2,#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row18_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 99.5%, transparent 99.5%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row19_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 98.5%, transparent 98.5%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row19_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 98.1%, transparent 98.1%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row20_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 97.0%, transparent 97.0%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row20_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 96.0%, transparent 96.0%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row21_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 94.5%, transparent 94.5%);
#         }#T_6f68f473_837d_11eb_b6ec_8c04ba3e1d36row21_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 92.3%, transparent 92.3%);
# piano_type = "AkPnCGdD", T = 20, note_intensity = "F"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-b5bd63c17228> in <module>
#       5
#       6 print('piano_type = "AkPnCGdD", T = 20, note_intensity = "F"')
# ----> 7 compute_scores_database_one_condition(piano_type = "AkPnCGdD", T = 20, note_intensity = "F", H_normalization = False)
#       8
#       9 print('piano_type = "AkPnCGdD", T = 20, note_intensity = "M"')
#
# <ipython-input-2-512d804ede8e> in compute_scores_database_one_condition(piano_type, T, note_intensity, H_normalization, adaptative_threshold)
#      49             for threshold in listthres:
#      50                 if adaptative_threshold:
# ---> 51                     prediction, _ = tf.transcribe_activations_dynamic(codebook, H, stft, threshold, H_normalization = H_normalization)
#      52                 else:
#      53                     prediction, _ = tf.transcribe_activations(codebook, H, stft, threshold, H_normalization = H_normalization)
#
# ~\Desktop\Projects\PhD side projects\gf\f\code\transcribe_factorization.py in transcribe_activations_dynamic(midi_codebook, H, stft, threshold, sliding_window, H_normalization)
#     124         for time_index in range(activation[note_index].size):
#     125             # Looking if the activation of the note is larger than its smooth value + threshold
# --> 126             minimalSustainCondition = (H[note_index, time_index] - activation[note_index, time_index] > threshold * H_max) # actived note
#     127
#     128             if minimalSustainCondition: # note detected and sustained
#
# KeyboardInterrupt:

# %% [markdown]
# # Avec normalisation des H

# %%
print('piano_type = "AkPnCGdD", T = 20, note_intensity = "F"')
compute_scores_database_one_condition(piano_type = "AkPnCGdD", T = 20, note_intensity = "F", H_normalization = True)

print('piano_type = "AkPnCGdD", T = 20, note_intensity = "M"')
compute_scores_database_one_condition(piano_type = "AkPnCGdD", T = 20, note_intensity = "M", H_normalization = True)

print('piano_type = "AkPnCGdD", T = 20, note_intensity = "P"')
compute_scores_database_one_condition(piano_type = "AkPnCGdD", T = 20, note_intensity = "P", H_normalization = True)


print('\n piano_type = "ENSTDkCl", T = 20, note_intensity = "F"')
compute_scores_database_one_condition(piano_type = "ENSTDkCl", T = 20, note_intensity = "F", H_normalization = True)

print('piano_type = "ENSTDkCl", T = 20, note_intensity = "M"')
compute_scores_database_one_condition(piano_type = "ENSTDkCl", T = 20, note_intensity = "M", H_normalization = True)

print('piano_type = "ENSTDkCl", T = 20, note_intensity = "P"')
compute_scores_database_one_condition(piano_type = "ENSTDkCl", T = 20, note_intensity = "P", H_normalization = True)
